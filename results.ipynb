# %% [markdown]
# # Election Results 2023

# %% [markdown]
# Downloading the election results from:
#
# https://results.eci.gov.in/AcResultGenDecNew2023/

# %%
import pandas as pd
import json
import requests
import functools
from pathlib import Path

# %% [markdown]
# ## Download Data

# %% [markdown]
# Data Organization:
#
# ```
# data/
#     states.csv
#     results.csv
#     constituencies.csv
#     S12/
#         features.json
#         constituencies.csv
#         001.csv
#         002.csv
# ```

# %%
# Chhattisgarh, Madhya Pradesh, Rajasthan and Telangana
state_codes = ["S12", "S20", "S26", "S29"]

# %% [markdown]
# ## The constituencies

# %% [markdown]
# The ECI website seems to have a JS file that it is using for rendering the map containing all the boundaries of the map and constituency details of every constituency in a state. The following code extracts the ac code and names from it.

# %%
@functools.cache
def get_features(st_code):
    path = Path("data") / st_code / "features.json"
    if path.exists():
        jsontext = path.read_text()
    else:
        path.parent.mkdir(exist_ok=True, parents=True)

        url = f"https://results.eci.gov.in/AcResultGenDecNew2023/ac/{st_code}.js"
        jsontext = requests.get(url).text.split("=")[1]
        path.write_text(jsontext)
        print("saved", path)
    return json.loads(jsontext)
    
@functools.cache
def get_constituencies(st_code):
    """Returns constituencies of the state as a dataframe.
    """
    path = Path("data") / st_code / "constituencies.csv"
    if path.exists():
        return pd.read_csv(path)
        
    features = get_features(st_code) 
    constituencies = [row['properties'] for row in features['features']]
    constituencies = sorted(constituencies, key=lambda ac: ac['AC_NO'])
    df = pd.DataFrame(constituencies)
    df = df.drop(columns=['FID'])
    df.columns = [c.lower() for c in df.columns]
    df.to_csv(path, index=False)
    print("saved", path)
    return df

# %%
for code in state_codes:
    get_constituencies(code)
# Out:
# saved data/S12/features.json
# saved data/S12/constituencies.csv
# saved data/S20/features.json
# saved data/S20/constituencies.csv
# saved data/S26/features.json
# saved data/S26/constituencies.csv
# saved data/S29/features.json
# saved data/S29/constituencies.csv

# %%
dfs = [get_constituencies(code) for code in state_codes]

# %%
df = pd.concat(dfs)

# %%
df.head()
# Out:
#    ac_no st_code         st_name     ac_name
# 0      1     S12  Madhya Pradesh     Sheopur
# 1      2     S12  Madhya Pradesh    Vijaypur
# 2      3     S12  Madhya Pradesh  Sabalagadh
# 3      4     S12  Madhya Pradesh       Jaura
# 4      5     S12  Madhya Pradesh     Sumaoli

# %%
df.to_csv("data/constituencies.csv", index=False)

# %%
df.head()
# Out:
#    ac_no st_code         st_name     ac_name
# 0      1     S12  Madhya Pradesh     Sheopur
# 1      2     S12  Madhya Pradesh    Vijaypur
# 2      3     S12  Madhya Pradesh  Sabalagadh
# 3      4     S12  Madhya Pradesh       Jaura
# 4      5     S12  Madhya Pradesh     Sumaoli

# %%
df_states = (
    df
    .groupby(['st_code', 'st_name'])
    .count()
    [['ac_no']]
    .rename(columns={"ac_no": "num_constituencies"})
    .reset_index()
)

# %%
df_states
# Out:
#   st_code         st_name  num_constituencies
# 0     S12  Madhya Pradesh                 230
# 1     S20       Rajasthan                 200
# 2     S26    Chhattisgarh                  90
# 3     S29       Telangana                 119

# %%
df_states.to_csv("data/states.csv")

# %%
df1 = get_constituencies("S12")

# %%
df1.head()
# Out:
#    ac_no st_code         st_name     ac_name
# 0      1     S12  Madhya Pradesh     Sheopur
# 1      2     S12  Madhya Pradesh    Vijaypur
# 2      3     S12  Madhya Pradesh  Sabalagadh
# 3      4     S12  Madhya Pradesh       Jaura
# 4      5     S12  Madhya Pradesh     Sumaoli

# %%
df1.set_index('ac_no').loc[1]
# Out:
# st_code               S12
# st_name    Madhya Pradesh
# ac_name           Sheopur
# Name: 1, dtype: object

# %% [markdown]
# ## Download Results

# %% [markdown]
# Code to download results of each constituency.

# %%
def read_table(st_code, ac_no):
    url = f"https://results.eci.gov.in/AcResultGenDecNew2023/Constituencywise{st_code}{ac_no}.htm"
    print("Parsing", url)
    dfs = pd.read_html(url)
    return preprocess_data(dfs[0])

def preprocess_data(df):
    """Cleans up the data to remove unwanted rows, renames the columns.
    """
    columns = {
        "Candidate": "candidate",
        "Party": "party",
        "EVM Votes": "evm_votes",
        "Postal Votes": "postal_votes",
        "Total Votes": "total_votes",
        "% of Votes": "percent_votes"
    }
    return (
        df
        .iloc[:-1] # skip last row
        .drop(columns=["S.N."])
        .rename(columns=columns))

def download_results(st_code, ac_no):
    path = Path("data") / st_code / f"{ac_no:03d}.csv"
    path.parent.mkdir(parents=True, exist_ok=True)
    if path.exists():
        print(f"{path} already exists. reused...")
        return pd.read_csv(path)
    
    try:
        df = read_table(st_code, ac_no)
    except Exception: 
        print(f"Failed to download results for {st_code} {ac_no}")
        import traceback
        traceback.print_exc()
        return None
    df1 = get_constituencies("S12")   
    row = df1.set_index('ac_no').loc[ac_no]
    
    df['st_code'] = row.st_code
    df['st_name'] = row.st_name
    df['ac_no'] = ac_no
    df['ac_name'] = row.ac_name
    
    # reorder columns
    columns = list(df.columns[-4:]) + list(df.columns[:-4])
    df = df[columns]
    
    df.to_csv(path, index=False)
    print("saved", path)
    return df

def download_state(code):
    path = Path("data") / code / f"results.csv"
    if path.exists():
        return pd.read_csv(path)

    df1 = get_constituencies(code)
    dfs = [download_results(code, ac_no) for ac_no in df1.ac_no]
    dfs = [df for df in dfs if df is not None]
    df = pd.concat(dfs)
    df.to_csv(path, index=False)
    return df

# %%
for code in state_codes:
    download_state(code)
# Out:
# data/S20/001.csv already exists. reused...
# data/S20/002.csv already exists. reused...
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS203.htm
# Failed to download results for S20 3
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS204.htm
# saved data/S20/004.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS205.htm
# Traceback (most recent call last):
#   File "/tmp/ipykernel_129361/1467209966.py", line 32, in download_results
#     df = read_table(state_code, ac_no)
#   File "/tmp/ipykernel_129361/1467209966.py", line 4, in read_table
#     dfs = pd.read_html(url)
#   File "/home/anand/.local/lib/python3.10/site-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#   File "/home/anand/.local/lib/python3.10/site-packages/pandas/io/html.py", line 1205, in read_html
#     return _parse(
#   File "/home/anand/.local/lib/python3.10/site-packages/pandas/io/html.py", line 986, in _parse
#     tables = p.parse_tables()
#   File "/home/anand/.local/lib/python3.10/site-packages/pandas/io/html.py", line 262, in parse_tables
#     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#   File "/home/anand/.local/lib/python3.10/site-packages/pandas/io/html.py", line 821, in _build_doc
#     raise e
#   File "/home/anand/.local/lib/python3.10/site-packages/pandas
csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2962.htm
# saved data/S29/062.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2963.htm
# saved data/S29/063.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2964.htm
# saved data/S29/064.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2965.htm
# saved data/S29/065.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2966.htm
# saved data/S29/066.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2967.htm
# saved data/S29/067.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2968.htm
# saved data/S29/068.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2969.htm
# saved data/S29/069.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2970.htm
# saved data/S29/070.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2971.htm
# saved data/S29/071.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2972.htm
# saved data/S29/072.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2973.htm
# saved data/S29/073.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2974.htm
# saved data/S29/074.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2975.htm
# saved data/S29/075.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2976.htm
# saved data/S29/076.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2977.htm
# saved data/S29/077.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2978.htm
# saved data/S29/078.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2979.htm
# saved data/S29/079.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2980.htm
# saved data/S29/080.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2981.htm
# saved data/S29/081.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2982.htm
# saved data/S29/082.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2983.htm
# saved data/S29/083.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2984.htm
# saved data/S29/084.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2985.htm
# saved data/S29/085.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2986.htm
# saved data/S29/086.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2987.htm
# saved data/S29/087.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2988.htm
# saved data/S29/088.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2989.htm
# saved data/S29/089.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2990.htm
# saved data/S29/090.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2991.htm
# saved data/S29/091.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2992.htm
# saved data/S29/092.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2993.htm
# saved data/S29/093.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2994.htm
# saved data/S29/094.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2995.htm
# saved data/S29/095.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2996.htm
# saved data/S29/096.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2997.htm
# saved data/S29/097.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2998.htm
# saved data/S29/098.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS2999.htm
# saved data/S29/099.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29100.htm
# saved data/S29/100.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29101.htm
# saved data/S29/101.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29102.htm
# saved data/S29/102.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29103.htm
# saved data/S29/103.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29104.htm
# saved data/S29/104.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29105.htm
# saved data/S29/105.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29106.htm
# saved data/S29/106.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29107.htm
# saved data/S29/107.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29108.htm
# saved data/S29/108.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29109.htm
# saved data/S29/109.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29110.htm
# saved data/S29/110.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29111.htm
# saved data/S29/111.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29112.htm
# saved data/S29/112.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29113.htm
# saved data/S29/113.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29114.htm
# saved data/S29/114.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29115.htm
# saved data/S29/115.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29116.htm
# saved data/S29/116.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29117.htm
# saved data/S29/117.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29118.htm
# saved data/S29/118.csv
# Parsing https://results.eci.gov.in/AcResultGenDecNew2023/ConstituencywiseS29119.htm
# saved data/S29/119.csv

# %% [markdown]
# ## All Results

# %%
dfs = [download_state(code) for code in state_codes]

# %%
df = pd.concat(dfs)

# %%
df.head()
# Out:
#   st_code         st_name  ac_no  ac_name                     candidate  \
# 0     S12  Madhya Pradesh      1  Sheopur  DURGALAL VIJAY (VAKEEL SAAB)
# 1     S12  Madhya Pradesh      1  Sheopur                   BABU JANDEL
# 2     S12  Madhya Pradesh      1  Sheopur          BIHARI SINGH SOLANKI
# 3     S12  Madhya Pradesh      1  Sheopur                     ADIL KHAN
# 4     S12  Madhya Pradesh      1  Sheopur                  YOGESH TYAGI
#
#                                   party  evm_votes  postal_votes  total_votes  \
# 0                Bharatiya Janata Party      85006           708        85714
# 1              Indian National Congress      95602          1242        96844
# 2                   Bahujan Samaj Party      22833           221        23054
# 3      Social Democratic Party Of India        729             4          733
# 4  Rashtriya Krantikari Samajwadi Party        233             1          234
#
#    percent_votes
# 0          40.45
# 1          45.70
# 2          10.88
# 3           0.35
# 4           0.11

# %%
df.to_csv("data/results.csv", index=False)
